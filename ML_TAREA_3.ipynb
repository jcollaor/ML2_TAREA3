# %% [markdown]
# <a href="https://colab.research.google.com/github/jcollaor/ML2_TAREA3/blob/main/ML_TAREA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd
import seaborn as sb
# import random
# Gráficos
# ==============================================================================
# import matplotlib.pyplot as plt
# import seaborn as sns
# from pywaffle import Waffle
# Preprocesado y modelado
# ==============================================================================
# from sklearn.datasets import load_boston
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.metrics import mean_squared_error
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import RepeatedKFold
# f# rom sklearn.model_selection import KFold
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import ParameterGrid
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.preprocessing import LabelEncoder
# from sklearn.tree import plot_tree
# from sklearn.inspection import permutation_importance
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn import metrics
# import multiprocessing
# división del conjunto de datos
# from sklearn.model_selection import train_test_split

# modelos
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import roc_curve
# from sklearn.metrics import confusion_matrix
# from  sklearn.model_selection  import cross_val_predict # 
# from sklearn.metrics import precision_score, recall_score, accuracy_score,  f1_score 
# from sklearn.metrics import precision_recall_curve
# from sklearn.preprocessing import StandardScaler

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Obtener Datos**

# %%
ruta = '/content/startup_data.csv'

df_data = pd.read_csv(ruta , sep=',')

# %%
df_data.columns = ["sin_nombre_0",
"codigo_de_estado", 
"latitud",
"longitud", 
"codigo_postal", 
"id" ,
"ciudad", 
"direccion",
"nombre",
"etiquetas",
"fundado_en",
"cerrado_en",
"primera_financiacion_en", 
"ultima_financiacion_en" ,
"edad_primer_año_de_financiamiento", 
"edad_ultimo_año_de_financiamiento",
"edad_primer_hito_ano", 
"edad_ultimo_hito_ano", 
"relaciones", 
"rondas_de_financiacion", 
"financiamiento_total_usd", 
"hitos", 
"codigo_de_estado_1", 
"CA",
"NY",
"MA", 
"TX", 
"es_otro_estado", 
"codigo_de_categoria",
"es_software",
"es_web",
"es_movil",
"es_empresa",
"es_publicidad",
"es_gamesvideo",
"es_comercio_electronico",
"es_biotecnologia",
"es_consultora",
"es_otra_categoria",
"object_id",
"tiene_VC",
"tiene_angel",
"tiene_roundA", 
"tiene_roundB", 
"tiene_roundC", 
"tiene_roundD", 
"participantes_promedio", 
"es_top500", 
"estado"]

# %% [markdown]
# # **Exploración**

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   sin_nombre_0                       923 non-null    int64
#  1   codigo_de_estado                   923 non-null    object
#  2   latitud                            923 non-null    float64
#  3   longitud                           923 non-null    float64
#  4   codigo_postal                      923 non-null    object
#  5   id                                 923 non-null    object
#  6   ciudad                             923 non-null    object
#  7   direccion                          430 non-null    object
#  8   nombre                             923 non-null    object
#  9   etiquetas                          923 non-null    int64
#  10  fundado_en                         923 non-null    object
#  11  cerrado_en                         335 non-null    object
#  12  primera_financiacion_en            923 non-null    object
#  13  ultima_financiacion_en             923 non-null    object
#  14  edad_primer_año_de_financiamiento  923 non-null    float64
#  15  edad_ultimo_año_de_financiamiento  923 non-null    float64
#  16  edad_primer_hito_ano               771 non-null    float64
#  17  edad_ultimo_hito_ano               771 non-null    float64
#  18  relaciones                         923 non-null    int64
#  19  rondas_de_financiacion             923 non-null    int64
#  20  financiamiento_total_usd           923 non-null    int64
#  21  hitos                              923 non-null    int64
#  22  codigo_de_estado_1                 922 non-null    object
#  23  CA                                 923 non-null    int64
#  24  NY                                 923 non-null    int64
#  25  MA                                 923 non-null    int64
#  26  TX                                 923 non-null    int64
#  27  es_otro_estado                     923 non-null    int64
#  28  codigo_de_categoria                923 non-null    object
#  29  es_software                        923 non-null    int64
#  30  es_web                             923 non-null    int64
#  31  es_movil                           923 non-null    int64
#  32  es_empresa                         923 non-null    int64
#  33  es_publicidad                      923 non-null    int64
#  34  es_gamesvideo                      923 non-null    int64
#  35  es_comercio_electronico            923 non-null    int64
#  36  es_biotecnologia                   923 non-null    int64
#  37  es_consultora                      923 non-null    int64
#  38  es_otra_categoria                  923 non-null    int64
#  39  object_id                          923 non-null    object
#  40  tiene_VC                           923 non-null    int64
#  41  tiene_angel                        923 non-null    int64
#  42  tiene_roundA                       923 non-null    int64
#  43  tiene_roundB                       923 non-null    int64
#  44  tiene_roundC                       923 non-null    int64
#  45  tiene_roundD                       923 non-null    int64
#  46  participantes_promedio             923 non-null    float64
#  47  es_top500                          923 non-null    int64
#  48  estado                             923 non-null    object
# dtypes: float64(7), int64(28), object(14)
# memory usage: 353.5+ KB

# %%
df_data.describe()
# Out:
#        sin_nombre_0     latitud    longitud   etiquetas  \
# count    923.000000  923.000000  923.000000  923.000000
# mean     572.297941   38.517442 -103.539212    0.646804
# std      333.585431    3.741497   22.394167    0.478222
# min        1.000000   25.752358 -122.756956    0.000000
# 25%      283.500000   37.388869 -122.198732    0.000000
# 50%      577.000000   37.779281 -118.374037    1.000000
# 75%      866.500000   40.730646  -77.214731    1.000000
# max     1153.000000   59.335232   18.057121    1.000000
#
#        edad_primer_año_de_financiamiento  edad_ultimo_año_de_financiamiento  \
# count                         923.000000                         923.000000
# mean                            2.235630                           3.931456
# std                             2.510449                           2.967910
# min                            -9.046600                          -9.046600
# 25%                             0.576700                           1.669850
# 50%                             1.446600                           3.528800
# 75%                             3.575350                           5.560250
# max                            21.895900                          21.895900
#
#        edad_primer_hito_ano  edad_ultimo_hito_ano  relaciones  \
# count            771.000000            771.000000  923.000000
# mean               3.055353              4.754423    7.710726
# std                2.977057              3.212107    7.265776
# min              -14.169900             -7.005500    0.000000
# 25%                1.000000              2.411000    3.000000
# 50%                2.520500              4.476700    5.000000
# 75%                4.686300              6.753400   10.000000
# max               24.684900             24.684900   63.000000
#
#        rondas_de_financiacion  ...  es_consultora  es_otra_categoria  \
# count              923.000000  ...     923.000000         923.000000
# mean                 2.310943  ...       0.003250           0.322860
# std                  1.390922  ...       0.056949           0.467823
# min                  1.000000  ...       0.000000           0.000000
# 25%                  1.000000  ...       0.000000           0.000000
# 50%                  2.000000  ...       0.000000           0.000000
# 75%                  3.000000  ...       0.000000           1.000000
# max                 10.000000  ...       1.000000           1.000000
#
#          tiene_VC  tiene_angel  tiene_roundA  tiene_roundB  tiene_roundC  \
# count  923.000000   923.000000    923.000000    923.000000    923.000000
# mean     0.326111     0.254605      0.508126      0.392199      0.232936
# std      0.469042     0.435875      0.500205      0.488505      0.422931
# min      0.000000     0.000000      0.000000      0.000000      0.000000
# 25%      0.000000     0.000000      0.000000      0.000000      0.000000
# 50%      0.000000     0.000000      1.000000      0.000000      0.000000
# 75%      1.000000     1.000000      1.000000      1.000000      0.000000
# max      1.000000     1.000000      1.000000      1.000000      1.000000
#
#        tiene_roundD  participantes_promedio   es_top500
# count    923.000000              923.000000  923.000000
# mean       0.099675                2.838586    0.809317
# std        0.299729                1.874601    0.393052
# min        0.000000                1.000000    0.000000
# 25%        0.000000                1.500000    1.000000
# 50%        0.000000                2.500000    1.000000
# 75%        0.000000                3.800000    1.000000
# max        1.000000               16.000000    1.000000
#
# [8 rows x 35 columns]

# %%
df_data.head(10)
# Out:
#    sin_nombre_0 codigo_de_estado    latitud    longitud codigo_postal  \
# 0          1005               CA  42.358880  -71.056820         92101
# 1           204               CA  37.238916 -121.973718         95032
# 2          1001               CA  32.901049 -117.192656         92121
# 3           738               CA  37.320309 -122.050040         95014
# 4          1002               CA  37.779281 -122.419236         94105
# 5           379               CA  37.406914 -122.090370         94043
# 6           195               CA  37.391559 -122.070264         94041
# 7           875               CA  38.057107 -122.513742         94901
# 8            16               MA  42.712207  -73.203599          1267
# 9           846               CA  37.427235 -122.145783         94306
#
#         id         ciudad               direccion                 nombre  \
# 0   c:6669      San Diego                     NaN            Bandsintown
# 1  c:16283      Los Gatos                     NaN              TriCipher
# 2  c:65620      San Diego      San Diego CA 92121                  Plixi
# 3  c:42668      Cupertino      Cupertino CA 95014      Solidcore Systems
# 4  c:65806  San Francisco  San Francisco CA 94105         Inhale Digital
# 5  c:22898  Mountain View  Mountain View CA 94043       Matisse Networks
# 6  c:16191  Mountain View                     NaN  RingCube Technologies
# 7   c:5192     San Rafael                     NaN              ClairMail
# 8   c:1043   Williamstown    Williamstown MA 1267              VoodooVox
# 9    c:498      Palo Alto                     NaN               Doostang
#
#    etiquetas  ... object_id tiene_VC tiene_angel tiene_roundA  tiene_roundB  \
# 0          1  ...    c:6669        0           1            0             0
# 1          1  ...   c:16283        1           0            0             1
# 2          1  ...   c:65620        0           0            1             0
# 3          1  ...   c:42668        0           0            0             1
# 4          0  ...   c:65806        1           1            0             0
# 5          0  ...   c:22898        0           0            0             1
# 6          1  ...   c:16191        1           0            1             1
# 7          1  ...    c:5192        0           0            1             1
# 8          1  ...    c:1043        1           0            1             0
# 9          1  ...     c:498        1           1            1             0
#
#    tiene_roundC  tiene_roundD  participantes_promedio  es_top500    estado
# 0             0             0                  1.0000          0  acquired
# 1             1             1                  4.7500          1  acquired
# 2             0             0                  4.0000          1  acquired
# 3             1             1                  3.3333          1  acquired
# 4             0             0                  1.0000          1    closed
# 5             0             0                  3.0000          1    closed
# 6             0             0                  1.6667          1  acquired
# 7             0             1                  3.5000          1  acquired
# 8             0             1                  4.0000          1  acquired
# 9             0             0                  1.0000          1  acquired
#
# [10 rows x 49 columns]

# %% [markdown]
# # **Análisis de datos**

# %%
sb.factorplot('estado',data=df_data,kind="count")

# %% [markdown]
# # **Datos Faltantes**

# %%
total = df_data.isnull().sum().sort_values(ascending= False ) 
percent_1 = df_data.isnull().sum()/df_data.isnull().count()*100 
percent_2 = (round(percent_1, 1) ).sort_values(ascending= False ) 
datos_faltantes = pd.concat([total, percent_2], axis=1, keys=['Total', '%']) 
datos_faltantes.head()
# Out:
#                      Total    %
# sin_nombre_0             0  0.0
# codigo_de_estado         0  0.0
# es_otro_estado           0  0.0
# codigo_de_categoria      0  0.0
# es_software              0  0.0

# %%
#na_values = ('np.nan', 'NA', 'NaN' 'inf')
#train = df_data.replace(na_values,np.nan)
#nan_rows = train[df_data.isnull().any(1)]
#nan_rows

#column_with_nan = df_data.columns[df_data.isnull().any()]
#numeric_shape = df_data.shape


 df_data["edad_primer_hito_ano"]
# Out:
#   File "<ipython-input-72-c27d1637a093>", line 10
#     df_data["edad_primer_hito_ano"]
#     ^
# IndentationError: unexpected indent

# %%
for dataset in df_data:
    mean = df_data["edad_primer_hito_ano"].mean()
    std = df_data["edad_primer_hito_ano"].std()
    is_null = df_data["edad_primer_hito_ano"].isnull().sum()
     # calcula números aleatorios entre la media, estándar yes_null 
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    # llena los valores de NaN en la columna Edad con valores 
    age_slice = df_data["edad_primer_hito_ano"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df_data["edad_primer_hito_ano"] = age_slice
    df_data["edad_primer_hito_ano"] = df_data["edad_primer_hito_ano"].astype(int)

# %%
for dataset in df_data:
    mean = df_data["edad_ultimo_hito_ano"].mean()
    std = df_data["edad_ultimo_hito_ano"].std()
    is_null = df_data["edad_ultimo_hito_ano"].isnull().sum()
     # calcula números aleatorios entre la media, estándar yes_null 
    rand_age = np.random.randint(mean - std, mean + std, size = is_null)
    # llena los valores de NaN en la columna Edad con valores 
    age_slice = df_data["edad_ultimo_hito_ano"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    df_data["edad_ultimo_hito_ano"] = age_slice
    df_data["edad_ultimo_hito_ano"] = df_data["edad_ultimo_hito_ano"].astype(int)

# %%
common_value = '1/1/2090'
df_data['cerrado_en'] = df_data['cerrado_en'].fillna(common_value)

# %%
#eliminar
df_data = df_data.drop(['direccion'], axis=1)

# %%
df_data["codigo_de_estado_1"] =df_data["codigo_de_estado"]

# %%
df_data["primera_financiacion_en"]
# Out:
# 0       4/1/2009
# 1      2/14/2005
# 2      3/30/2010
# 3      2/17/2005
# 4       8/1/2010
#          ...
# 918     7/9/2009
# 919     4/1/2005
# 920    6/29/2007
# 921    10/5/2009
# 922    2/13/2006
# Name: primera_financiacion_en, Length: 923, dtype: object
